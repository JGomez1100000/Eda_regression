# %%
import requests

# %%
url = 'https://euw1.api.riotgames.com/lol/league-exp/v4/entries/RANKED_SOLO_5x5/CHALLENGER/I?api_key=RGAPI-53593657-22d4-4565-a810-0cd162280c33'

# %%
# Realización de la petición GET
respuesta = requests.get(url)  

# Imprimimos el código de estado en la respuesta (response)
print(f"Request {respuesta.status_code} : '{respuesta.reason}'")
# Out:
# Request 200 : 'OK'

# %%
# Obtenemos los datos y los convertimos a JSON.
datos = respuesta.json()  
# Imprimmos los datos que los hemos convertidos a JSON.
# Podríamos usar print(response.json()) pero no se imprime de una manera correcta.
# Nos ayudamos de la librería pprint
import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(datos)
# Out:
# [{'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1824,
#   'losses': 537,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'J5qBaV6G_yzlkoMmyhdZ8MNMEz_kEGWBsG9NpRPjBweWZfDR',
#   'summonerName': 'NattyNatt',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 626},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1757,
#   'losses': 211,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'DgjHY5TXZ2RzAVgBxPv4l3yVurzDMiaPHnytOF4W7rgsH2U',
#   'summonerName': 'Razørk Activoo',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 293},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1590,
#   'losses': 329,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'Bz89KoPOnCfJ0XeATw5OY3BRdSeNXpylI5gZiTmX8zzRDTw',
#   'summonerName': 'WOOOLITE',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 413},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1568,
#   'losses': 147,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'q8k_YgHmwi6QIsbH7ehmbOeGPgjHyZXQ1xd_SCtzF2juBmyAvhu1lre9MA',
#   'summonerName': 'Stomme Eend',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 235},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1545,
#   'losses': 397,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '5XlaL-UN5fE5aoxDTWLZm-XFW_R_-wLbzJQ5fwoUbACdAfNoRyMwCUJnhg',
#   'summonerName': 'frygo',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 465},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1531,
#   'losses': 160,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'M1QE7bNdhGGLX3-b7UeOf5NQJXBiGWmfQxC7wHCeI6ZexN0',
#   'summonerName': 'DzuUwU',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 230},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1528,
#   'losses': 287,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'uhceFi1O1Dhp7fU0OuaW2xfq3dECuq_FaZh-EI0KPuhmGSo',
#   'summonerName': 'Thumbs Down',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 362},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1527,
#   'losses': 243,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '1wQj4s6FES_L7DidngGGRai7pOb7fi_FvRzyVsR3GQO2iGI',
#   'summonerName': 'AHaHaCiK',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 309},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1513,
#   'losses': 164,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '9sEEDyB8tEjNsrntAcNpElTqIKNK3aqG5HJZwC08mcjA36o5N8W1B8P_EA',
#   'summonerName': 'Molnigt',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 220},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1510,
#   'losses': 245,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '1IGvA60stUNxmmj1nZNecfJ9gfvl7Hn5i76L3Qmch0R049Y',
#   'summonerName': 'Agurin',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 327},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1507,
#   'losses': 60,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'kG3BStPT1pyPfFCPwimUqsowGGkq8w_q-H9JN19nOt0jY_437H93RUuJFw',
#   'summonerName': 'FUR Ayu',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 138},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1495,
#   'losses': 335,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'n3VP5OBXpAKjmZD3AqDYyp45RCgOfHf4LPVnLjbE0pR7_xGd',
#   'summonerName': 'KC NEXT ADKING',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 415},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1486,
#   'losses': 99,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'O4a68AGyiMbSHFWL-KFv6lIt0OfQWvI70xIYuuAQ6A0tSEo',
#   'summonerName': 'Lekcyc',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 156},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1455,
#   'losses': 110,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'G1Rn7mTzHL9-089SxUSq_K62ZPnsQCVOQiWbPSuXPJbMs54',
#   'summonerName': 'Kieran Tierney',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 172},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1438,
#   'losses': 217,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'bP9AljOVJIHe77pwmy8Om34sYNWg8ncb_NCOakN1SwcLbyY',
#   'summonerName': 'TakeSet sama',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 274},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1409,
#   'losses': 304,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'CjbfXjh9qiBLxPjaGFkak-ut-jTMrK8o7YiXIGWpz1_TAxM',
#   'summonerName': 'Odysseus131',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 369},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1397,
#   'losses': 119,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'ryLV40Fsl9-zEh1iHnGCeKx1muk5tIAMMXFt_YP0RK3_yVDQr5jqhCN-Yw',
#   'summonerName': 'its not over',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 181},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1380,
#   'losses': 231,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'dunSZOsk5xFb79u8cyFW0RBK7UUJXkeNzGNpaUaADaZJhoA',
#   'summonerName': 'XZX',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 297},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1377,
#   'losses': 280,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'F5wgvQR10q6gk8ZJQvqIs3MX1O2erasFfwjIB_UCAG9VDy4',
#   'summonerName': 'the inescapable',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 357},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1361,
#   'losses': 255,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '7i2wlU4gsM2BZvjdwTpZpH8RwNsmwca5vKhqQSSOa2NQU3w',
#   'summonerName': 'GO toucouille',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 309},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1342,
#   'losses': 270,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'ApLMzo1xUXConLa9LqNbxRJZjvRjyY7c4qPhYZ3qrEciSRw4V_oS5v1zVg',
#   'summonerName': 'Thomas Shelby2',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 337},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1341,
#   'losses': 195,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'RQORgwxq88JggtQyReJh6dLP2sWhSF7PQWXDt6Wz98PSAJE',
#   'summonerName': 'Sir Leywin',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 253},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1335,
#   'losses': 137,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'q1QCkC0X4N3A0pP3Db933xWeVWFF3CAKZoOG0pdKMuuxda8',
#   'summonerName': 'Peng04',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 181},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1328,
#   'losses': 276,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'HAh2KqYvmWmteFmVH4RYOm_ezxELp0qZ7w-RMK-ZIY7Ny3o',
#   'summonerName': 'OSCAR MUÑOZ',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 335},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1327,
#   'losses': 341,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'xiYxjPXMtKEmIvZ1QzqzAiUbtRPCD2_atF82NdpeDocNRMU0secidpeEjA',
#   'summonerName': 'sanghyxxn',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 423},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1326,
#   'losses': 282,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '5EJHYXpFe9XN5EaKOQfrRiAMh0aHOKq4csq_HDc3Swr2DtE',
#   'summonerName': 'XL PJ',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 349},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1304,
#   'losses': 360,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'tLtzG0VteMuGTUqhJsHKOjGhBewYHajdT8AWpZki_wK-qL8',
#   'summonerName': 'Grizzły Hills',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 415},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1302,
#   'losses': 100,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '1rDh335JP8Vq7WSQPKQTp2VkAao9uXsz6V_bIu7jtIt93G3_',
#   'summonerName': 'xLinayaa',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 159},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1301,
#   'losses': 237,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'd_3yYK0e_uJYLtvi7VgWTxd5qTa1aQkjr_3V6GE2nG8RyV0',
#   'summonerName': 'Me Wo Akeru',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 283},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1289,
#   'losses': 473,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'PYk5xEhl7qLFDAMv0XpHrKE3pvfOjhYznls2st--YBuny34',
#   'summonerName': 'M1dLaoban',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 533},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1285,
#   'losses': 382,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'Qq9l2gfPQNzDLSg1pwe9tZbNYQTTMlrO8EM2oDprJ8H15Ao',
#   'summonerName': 'twtv habuubu',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 445},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1281,
#   'losses': 141,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'pcRrrwtnVsAwgoQkCpCJggeTu6yxj-gIK9MJi4_UALzne6M',
#   'summonerName': 'AbbedaggÆ',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 186},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1273,
#   'losses': 405,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'rQziWbPPxrOvp115RJdAYReFxve61Cuq0QwwZLkEYnDvEuls',
#   'summonerName': 'METROOOOOOOOO',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 469},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1271,
#   'losses': 487,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'BfSea6ghOB4lN_VxFwSiiCqyHapY2i7LUjT-YlY7GgNAJOA',
#   'summonerName': 'G2 Joker',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 562},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1265,
#   'losses': 300,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'YzyFT0b2KuzjadiZqTy0cEKBGV0GKWoyFylQhmnf2AQFyM8',
#   'summonerName': 'Dzu',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 340},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1264,
#   'losses': 510,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '8IZkJceaIpeDWTFi3ZcKlzpbZcyN7_N6-rTpHocDT4dWLkU',
#   'summonerName': 'shenxian23',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 563},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1263,
#   'losses': 270,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '64gFPiZSq3wbubKsJ82ILBNWVwpsvptP-LPskJLkszTYf32okLhkHcCltA',
#   'summonerName': 'Yuuri Leo',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 318},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1261,
#   'losses': 415,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'X00YHs7gUsJpY_aMWlZWhuhaK_cpYPyaA083R3O9VHJvifU',
#   'summonerName': '15th July',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 472},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1256,
#   'losses': 158,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'gEjtXIZJBpxp0SSS-_ZpJbCGO_saYavtAjMrXx4zrEZ_Olnykxi4V3K6mw',
#   'summonerName': 'Mαster Oogwαy',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 208},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1254,
#   'losses': 87,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'x6hKmIy4EPbGvendWl7QgO2T_MA3O3dTBd-Y80lCMI9KBYnmv8W4OVBuIA',
#   'summonerName': 'choosetosmile7',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 139},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1253,
#   'losses': 721,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'UCExV4Tvycu0vOwOgZ9fPO3EWbYovofAUp7ZxYtl4jrvlz4',
#   'summonerName': 'qwqw',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 789},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1253,
#   'losses': 389,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'KdV4P0zyBuDT4bM0JlL6Q66fD5sNzMvNoa3xPdDKWqyYdExIlstdeBZWog',
#   'summonerName': 'SPOLFCEI',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 446},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1253,
#   'losses': 215,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'nNEhsbqNSvn_BWiKKLTAHnvLQo7Ye5VskjHSHDcS3fpzjOJy',
#   'summonerName': 'TwTv Kaos Angel',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 264},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1252,
#   'losses': 155,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '3oMV_ASvwmVB_9-TmsDlueCoVeJaYf-FmkXNqNpIbyrCpC0',
#   'summonerName': 'Isagi Žnjoichi',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 203},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1246,
#   'losses': 72,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'Dhjh-PLXhMXkYPwSHSimPQQWOzlsFnONq-z5VNR-QTiBlas',
#   'summonerName': 'Wataru Endo',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 116},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1239,
#   'losses': 255,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'kTaTQfq3WJYH2MrNu-1wTQnGpeY0TjzLNHCVGItM-ZlHqKU',
#   'summonerName': 'zeus manchego',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 307},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1235,
#   'losses': 322,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'R1ApS6Ci1NHEfYKutO4PW8WH3RNtXk0bycQHrnseJQ2JWzLB',
#   'summonerName': 'hovinko z kose',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 361},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1234,
#   'losses': 134,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'l1ZqFoFf2vX-Wm8RNEnEh21pl6NlxOvOw6xXt9LWEceCARnV',
#   'summonerName': 'Mountain Wolf',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 171},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1230,
#   'losses': 108,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '8Q-m0Q_H0gl4Sfe6QOVV3A3ZOV4sfk8vekCBrJ6YnlivMrE',
#   'summonerName': 'worst sona world',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 161},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1229,
#   'losses': 137,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'QbBGkZwSmCR6ktps9pAa5vBYRxdmydvYDNj0LjdEc4Jbaac',
#   'summonerName': 'Stack Collector',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 187},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1228,
#   'losses': 214,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'cAtRWbi9oA3c3S2aOCMc47KqxzQuXAEykv1cyAQKKWAwS-_8kKhcg6TrJw',
#   'summonerName': 'sdfsdfsgert',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 271},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1225,
#   'losses': 183,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'pkhWQ_RxjoAM8I_v81JSYgp-d62hdtc4lN-hSxM_-_qwbFAT',
#   'summonerName': 'ANDARlEL',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 228},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1221,
#   'losses': 138,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'S8JX7JQsJuPLDAv--ZM604E0RX7HIdNr8gaztxv9yUpWVug',
#   'summonerName': 'FUN k3y',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 188},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1219,
#   'losses': 118,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'aHTjzCje-TnFMWIF5uNkZRYPhkvikWTjVlSgt93Y-2FAgbk',
#   'summonerName': 'Boukada',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 164},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1218,
#   'losses': 99,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'Cbaz3NNvVAsXhGMPjZ2sbxUedCL8m68DWYrdL_j9cVUyGTaC',
#   'summonerName': 'Worst Zac EUW',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 150},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1214,
#   'losses': 404,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'UdCySNnu4GjA8CKOVGWufnvIkQSt1UMynDKhdj4-Iul4K5E',
#   'summonerName': 'TwTVxKenzuke',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 447},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1214,
#   'losses': 226,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'nC_9B_j6Xp3pSpuUCtmwVtovVXXVD8h-7wFq5SV2-hKS-fw',
#   'summonerName': 'pocovirtuoso',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 271},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1210,
#   'losses': 276,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'd3uZTwVJjoxi63wOGuJPm6ZzR-KjbMEldlbfaN0YCumjvoHm553hbi6R5A',
#   'summonerName': 'TheShy offspring',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 328},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1206,
#   'losses': 155,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '_I4pTvSqFuwD_xxlOEn0_tuz3FsgW8rtsFlUbLQtuZInxA-GRX_KZB4EMQ',
#   'summonerName': 'Reborn Berkan',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 215},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1205,
#   'losses': 101,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '9IGZBrILipePym_tx63jvvTewuFtRlkFdO_hdE6fUvtGctI',
#   'summonerName': 'f3ed l0rd',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 146},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1204,
#   'losses': 236,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'HHUCxKLtEhkn1jh4Gly5CxtnsCvjdTkdqCwrFDrWYsf9G7t3LWC9MSVRTA',
#   'summonerName': 'Subgainer700',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 301},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1204,
#   'losses': 100,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '0AxsaPs89BlcdV-khyMNSgpw27GLMpkWyJhis2z_Op_uVxUD',
#   'summonerName': 'Hyweedri',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 151},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1203,
#   'losses': 379,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'vab6AZlVZWRKw7O_s74JbQr0cmWgqr3S4YAlNvZZiy79OznoAPHvYkaQpw',
#   'summonerName': 'I Love Uber Eats',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 423},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1201,
#   'losses': 122,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'HUhKpXIs5v59pPWxM0j3zhxNk_a9vYMURg7UQWk_grXwBsHRl1YrTBVdcw',
#   'summonerName': 'månebarn',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 215},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1200,
#   'losses': 360,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'BNEDV9nK1xR2_DGvfvAqruXgqXMWKdi7vSVKKi_yxMQzcr0I04XwEsNLmQ',
#   'summonerName': 'Kimchi SUP',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 434},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1199,
#   'losses': 422,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'TxvIYYvEW7gIvYsRB_vHpw-2q4FqckhO7UaRUZmJKrM4mpo',
#   'summonerName': 'Experiment 604',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 473},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1199,
#   'losses': 186,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'NNPVPAEq5PZHcfNYdxInjJPw8_eqht4KBpn_3FfYY1V7plQ',
#   'summonerName': 'sootrebor',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 239},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1198,
#   'losses': 160,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'sC-7Hlg8BPI7iUCURdKbhY_RYdjBXR4txa6CPBWVuRN-Y_pM485iCGVCuA',
#   'summonerName': 'TwitchTv Zy0xxx',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 238},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1196,
#   'losses': 196,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'w7wyU3YkQTpdlRw-w2tfHME8-HoZMQlj1mkLZLjg90G_Z7o',
#   'summonerName': 'Dragdar',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 242},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1196,
#   'losses': 122,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'mbF3Q5F3MUmzOjxrDZ9o5xbfsnh2ewwJQTNC4BSz-oTIG3o',
#   'summonerName': 'PatkicaA',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 168},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1193,
#   'losses': 64,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'qUoSchMm3lwuNjsVyggsAciyDs_9S7tKi1divx-6SCBbnznHrW6GgLRgMg',
#   'summonerName': 'asdcxc',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 116},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1190,
#   'losses': 506,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '1PwKFSMqifytuG7dbLRUjh8ubWXXu3CQPN_qPrZOxqbVpYIb',
#   'summonerName': 'TTV H0rnlime',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 559},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1188,
#   'losses': 267,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'nJqVNJ7UgNv80-jY-smrLa-UD4uZPmBdD0F4s0un9iV1edc',
#   'summonerName': 'DizL1',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 317},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1184,
#   'losses': 249,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'tj_OszD5yhDCpPmjv_njOLI-JBatcG_GFJuMqS_XJAcs3aLG',
#   'summonerName': 'Pusi Puu',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 300},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1182,
#   'losses': 91,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'gXAvRKWTJOCfrRdEQQvyN-kPlCgFbX8PZhkyQyt6Bls_adj74IwLFtY4EQ',
#   'summonerName': 'Anothertomb',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 133},
#  {'freshBlood': True,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1181,
#   'losses': 290,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 't8WNmtEhAD20QIs4l5Ao1_dNnQ677EQO6pWum_3N8c2eWV_I40aBKJrllw',
#   'summonerName': 'Photon1',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 347},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1180,
#   'losses': 356,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'I3PWE-1KL3yiAQC4zom9W9n4gyPIvfTt1VfQzhq0haXrPjs',
#   'summonerName': 'Crowno',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 404},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1179,
#   'losses': 168,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'Thf095zID37t7kFgd8-KogjIStSlU2Q2AnTc1K_XDfxOALxS',
#   'summonerName': 'Drututt',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 212},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1178,
#   'losses': 94,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'ZJCYwtZjuGR_jspWdjh5Q75k_2SSxBNrk8qc7Rro_ondVd9p',
#   'summonerName': 'zhypey',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 128},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1176,
#   'losses': 234,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'p1v307T_wG8lQro_TFrDNANKMOt6_4jnT6gJ-QuMs0221Eo',
#   'summonerName': 'Jαvier',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 279},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1171,
#   'losses': 233,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'K1YfJ-LbayabC-uyNCvq_2ldXO9bkW9DM6myKexj4Eua5eI',
#   'summonerName': 'Veignorem',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 271},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1171,
#   'losses': 97,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'd8QMvH0y4j-aoFf9ha0iij7yvU_-WBVey2bCYhhMeHsir7SY',
#   'summonerName': 'Heroic Miracle',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 161},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1170,
#   'losses': 245,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'cU542jI7fcZzq2T00FnQoN_RiRoy_Pl8k2zN0wbBVVC9aNQ',
#   'summonerName': 'WP GG XD',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 287},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1168,
#   'losses': 171,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'e83PBz08Vw13ys8qSoxHX3U8-eESqJWHRpClPwjCJP_FS5UhwkdlHdjiMA',
#   'summonerName': 'Being left',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 233},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1168,
#   'losses': 166,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'rjWwaRK55lhfA1shsYGgziRWaZW1i5muT2OpBXl2XFoUkNpj',
#   'summonerName': 'Sebekx',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 212},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1168,
#   'losses': 78,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'IziR2eGQfo3tUSMBD0vD_GA5zMdzOaBk2lqopVL54T-s1zkz9hbQCiCSIw',
#   'summonerName': 'Ice0713',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 148},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1165,
#   'losses': 98,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'bCG3vX6TRljvtodIfWMtbBWp-LESs1DOdbY6yhCH3WB0c0T_XHVZEw10EQ',
#   'summonerName': 'ImJustAKid17',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 133},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1163,
#   'losses': 313,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '21D3Y5qKSktkd7agdIZAdBPbvj7CRIO7A4-QU3Qj6UeSCU-J',
#   'summonerName': 'G2 Susamaru',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 360},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1163,
#   'losses': 235,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'F6KzktSmyJ-ArawxnEC3TlTx3rJVGQeqQj3y4gTSPAydRpo',
#   'summonerName': 'GW Villager',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 285},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1161,
#   'losses': 131,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'FGG6RgHUYMtUi5kQraVG9m1G09q1xH4kvz0qJ6C2_As8aIA',
#   'summonerName': 'Schuhbart',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 180},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1159,
#   'losses': 587,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '3SbkJk-qRVVXvM3Vs50EcDus8mNoZjNvSS-z5BJhkmHf1EJ1',
#   'summonerName': 'Groot L9',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 627},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1158,
#   'losses': 356,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'gvSUWX2o4eGzIDAyPnrmp-vyR0g7f2s4QfU4Y1o1nT090pg',
#   'summonerName': 'dajor25',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 415},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1155,
#   'losses': 132,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '4tieSjF7k-VSq0jGnVapaoxHe9yJ6hA_uYAj0DykVejmQ28hmb_DShYlZQ',
#   'summonerName': 'TTV suki545',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 175},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1152,
#   'losses': 133,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'daY16czGgIUieVJFYYt15gmyyJp5W0uKrbdYWTf8PXkubmLV',
#   'summonerName': 'K405 N815',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 188},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1152,
#   'losses': 74,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'ShbaCafTci354lvbhgKo9X_Hus2GsMnQzTMUgYTOqEye7MAius6sUo0brA',
#   'summonerName': 'goodtoknowyouhah',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 108},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1150,
#   'losses': 227,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '9U-dXnaYV7wwOdeR7K3bO4PTE2bUqu4iFxrDk32UDpFmXug',
#   'summonerName': 'artistic turtle',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 271},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1149,
#   'losses': 245,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'm5-vnpRwqwATAAu8M81uWsSqfmKhxDnfWn5-mttgbqEBEAU',
#   'summonerName': 'Nomi',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 304},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1147,
#   'losses': 183,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'qpE5_SAMkfIvWeP5cwnzG7rNfR9uRwLUxtPW_hPlygyCo-Y',
#   'summonerName': 'Porsche Kaymin S',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 221},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1144,
#   'losses': 500,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'ZkuQL4DYDUwNpAYXjllzU_RSQjekliOg-JulDCFzOq87bfo',
#   'summonerName': 'i can fight',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 558},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1144,
#   'losses': 239,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'K0b5qgt2u-sAhRzDH5XlDHBtCk0Szxeg31M3sKVi5NK_YtM',
#   'summonerName': 'DONATELL0',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 283},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1142,
#   'losses': 180,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '6PjQq_S3Fs325AQ_-X3Zkab_qSSRLwJTKlyDPOj4Frv9Tk0',
#   'summonerName': 'Maynter',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 220},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1140,
#   'losses': 116,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '7ntRBlpECrvOZEtz9p7XZT5KdAfuWVDOVx-xnZGNBimnP_Y',
#   'summonerName': 'C9 Veigar V2',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 163},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1138,
#   'losses': 160,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'pN4frG5_HJg6WTQfspA1UKPttgbDzFGLNmRNZgwLO4WNvsQ',
#   'summonerName': 'Sebeks',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 206},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1133,
#   'losses': 147,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '-oIGHPekpDQfsBh8XH1VPEUztFk-sXAfhUCGMmSb6QaScZU',
#   'summonerName': 'ayekasia',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 189},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1132,
#   'losses': 349,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '3zIuLbxNyBCCHVBDTe4hLyAS3nuvxo-RyN2aSQ3M9VguPNY',
#   'summonerName': 'Guillermo Gombao',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 401},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1132,
#   'losses': 246,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'j4mqDfYQeGt5bvOXDJFrRNOCuD2VTm8YXRIRjW-2m-5MOOs1wmI_pRBAOw',
#   'summonerName': 'GarbageTrashLane',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 300},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1130,
#   'losses': 504,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'NU6W3rBtBr2qnMwzOnIne0g5j6x_rkBDCIcKJaY8uGTVgeA',
#   'summonerName': 'IWILLC0NQUER',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 560},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1130,
#   'losses': 227,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'tx-mei4UFJkMhPSJThki3d1HeTAUWCEToGyZwYW56qGgyJS8rK-2ueBJtw',
#   'summonerName': 'AgnwstosPente',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 282},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1130,
#   'losses': 118,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'VDccKKiffl7aY8GE9eCQHVoXaC4lehCUQ2CVhDVOyhSVaok',
#   'summonerName': 'INT Baul',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 170},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1130,
#   'losses': 110,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'ri4ZyziQf-uaEDXPa-sOVx0ihAqq0sx3Hos3OeqYWrtxyjhToPUatXyaag',
#   'summonerName': 'u good me better',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 153},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1129,
#   'losses': 351,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'OdU7Dga3y_YpXUc1sZ_QgUd3iZtmpGXH_mBjXbKRf0-8lc0',
#   'summonerName': 'messi sup acc',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 392},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1127,
#   'losses': 177,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'dtCYU211crNySuMfNG-E62FquFfB6CbQKiX8vpJlm0KO_2M',
#   'summonerName': 'Xicor7',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 226},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1126,
#   'losses': 467,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'TFNly98JiRZgdgZdz6bIZR8W43iM2We0SIh10K8buFWP-Lg',
#   'summonerName': 'sharynne enjoyer',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 508},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1123,
#   'losses': 127,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'uHz29LMxJ1JI9-Z4LETiftPPBL-2urIr90LER98Dbf3HdoGs',
#   'summonerName': 'name change luck',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 185},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1122,
#   'losses': 558,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'yu0LnGpQpuBQQfkFdW-9n0Nr_bGe1Dh-ElZ-2S1srA2pPws',
#   'summonerName': 'Roulette',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 614},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1121,
#   'losses': 308,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'yJQvdXHC3ClLX8638xApQXGM5vrLLfJrsn_4WofbssbWGPk',
#   'summonerName': 'BDS xMatty',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 363},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1120,
#   'losses': 292,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'DXn-t6qLssmYI_6I7U0PQrwUVAzdHHs4LpTH7rFnwYZA-PyhrAVzIgpohQ',
#   'summonerName': 'LEC ADC 2024',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 339},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1120,
#   'losses': 134,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'hus0-mmSbnaJ2VYncFEChcE2M2-LNeI2--qwgV7p9YKsmGjJFMV8BB2XLA',
#   'summonerName': 'Ziqmo0',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 177},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1119,
#   'losses': 72,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'D7-ZkJRNeHxDJpj4zS0-fs_vax1M--WyFn4CJV17brWJuvQ',
#   'summonerName': 'CookieHub Diff',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 131},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1119,
#   'losses': 39,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'uZj5Y2H-J6xuEwSh2sxfoVw4GR2Z2BxR6N0lF0S_AhOS4d4',
#   'summonerName': 'N1ghtingäle',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 74},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1118,
#   'losses': 221,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'AWabAuX737TdLcRNhJtcNYuMHDBwgCCp90RZbWFjlNWci7s6',
#   'summonerName': 'SLT 2',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 267},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1116,
#   'losses': 167,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'LJwVPFpdDBLXXXkN-DDO-op2J68mKsjKce2MlxYlhtSbQLU',
#   'summonerName': 'Delitto',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 209},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1113,
#   'losses': 253,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'jfCUz_uRqTfF329ySHyJpZu5foP3A2la9zD6R3uo0KMz2i0',
#   'summonerName': 'Heavenly Scars',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 300},
#  {'freshBlood': True,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1110,
#   'losses': 252,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'o5LL7mtAe8P2ERf5Eo1Xm1-gtxfX8tLiIoFmhm40Nz2WRgQ',
#   'summonerName': 'WindLoL',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 293},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1107,
#   'losses': 275,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'W-iSfH6J15uKm2JSYF2wr9x4zHDTZyJFrImKDvRSw3Ma3BQ',
#   'summonerName': 'Worten Sempre',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 327},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1107,
#   'losses': 199,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'zVvCDLgtY-lXB9ooCSKWqEIUqfe72b_lSiCtBy3lHUipQGQ',
#   'summonerName': 'Odoamne',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 237},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1106,
#   'losses': 270,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'YL0zND8ArYuBelJDoVY633iJTPE0DrTj3EJwU2dJ2niZC3dx',
#   'summonerName': 'zrh2',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 317},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1106,
#   'losses': 141,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'UgLvw4mpnO0FShYAgCB37hCKbj4ZoUfPhRj-OiJJfVYMMva5LWhskWbMxw',
#   'summonerName': 'Anathemas',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 210},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1106,
#   'losses': 108,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'QZtgWwM9mF9HtAoE7R1zPk6_lTIIbfBYghqhCIOQ7QvXcWChOAdBFavGTw',
#   'summonerName': 'Noeyim',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 168},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
# ...
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1079,
#   'losses': 52,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'fEpWy-7KY5Iabk0xEuQb650ShqHzuvxr3tSejqLjSSZLRbA',
#   'summonerName': 'ÂDC2k17',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 99},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1078,
#   'losses': 127,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'DC7oncmAlDWjXHEPk3Klj98MUVBoSyAaBa7Z2xVqdjLn_S4f',
#   'summonerName': 'GAREN256',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 164},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1076,
#   'losses': 393,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '2KhvUuaZvfo-I_zXTueFYMtIzaMnsjs1Q3IR2Wzqg6RAans',
#   'summonerName': 'MDB top acc',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 440},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1076,
#   'losses': 272,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'I8QYiBnyS8dgXe-cW0uCNlsPh7pBClNeFg7ImB0hpj21wmsudlTluV08hw',
#   'summonerName': '2023 SOLDIER',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 308},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1073,
#   'losses': 414,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'cGLOpD7S0SIWpqcGNUku2VIksErnm2H_fq2of3Dbfymsi1U',
#   'summonerName': 'Wesley Warren Jr',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 467},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1071,
#   'losses': 409,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'yKts24kvQ4DnVlW_TLJCWKdTaPopbm54iikYexOU2hG4VrnT',
#   'summonerName': 'RhiIech',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 453},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1070,
#   'losses': 532,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'C_qkNx0u0ypBDEZIztyIrKWaLaR8RnEpFZISaJHleX-nsq0',
#   'summonerName': 'TheRoyalKanin',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 576},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1069,
#   'losses': 210,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '6Zsm6NMwOIcYGmxOt-8GNEJkxYrmVZTR7rLeuLa_5wXvK9M',
#   'summonerName': 'ni pitié ni rien',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 288},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1069,
#   'losses': 184,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '-7R7SSuhyNspzq7FlZ_r0HCbvF9ETHThLYCH6S39HIztMHZI',
#   'summonerName': '113 777',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 241},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1069,
#   'losses': 140,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'VYg7rjXYoQbLKIEfz7PaclfAIF_hHFSF89XqCAlCZKh9KH0So0j5iVPRgQ',
#   'summonerName': 'haplarimi aldim',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 198},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1069,
#   'losses': 98,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '1ofzSgm9mjVxO1IUxa46t4iPyCZXxXQCzJWtdl2YJg5snH4',
#   'summonerName': 'Shαwn Frost',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 134},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1068,
#   'losses': 181,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'hROOijgJFYRuPcrQihWAt-407zbQyEx_06jnGvrLkkyAJmrE5EuIMXJyfA',
#   'summonerName': 'Groinze',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 219},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1067,
#   'losses': 142,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'mhrWR0kK_JsaazB7lIHTHGqBafgjJ5vaRGtTkroTadhi_W5h',
#   'summonerName': 'NIKOLA JOKIĆ',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 189},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1067,
#   'losses': 140,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'z_Ox4s5SQ27OH-QyYq1WAxFRODNuPFvW2G8RxVikeZIveH8',
#   'summonerName': 'Rell Pyke OTP',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 177},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1066,
#   'losses': 235,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'iv0Z9Peuxu-h1Ni5o9gAaaS56MfS3Gi-vZDO65biGom-gUM',
#   'summonerName': 'NEVER WEAK AGAIN',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 269},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1063,
#   'losses': 161,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '5x-CfXYho8uu5I7WB-ArXJoXcN4n8wOngfavGdXwgvxzFE7y',
#   'summonerName': 'Riven PhD',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 217},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1062,
#   'losses': 320,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'kNJgiJt_CqZsrv3vbCAerkK5g5Bmuiya2vzAooVaHCMCy6w',
#   'summonerName': 'TTV Potent213',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 370},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1060,
#   'losses': 476,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '_pRruSITpetlhIw_hKon0eQa3uaEzdgnTQQ_Du7OyCuXpvk',
#   'summonerName': 'B Ζ',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 516},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1060,
#   'losses': 220,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'zvtu60jDg1ng72wYmRAD4mwG8sjWXn1WF3OzwWrjvM0VEvc',
#   'summonerName': 'den store mand',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 262},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1060,
#   'losses': 197,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'G838-53rNkJ0ZISeof1IEcn250QV4fLhbZRkL4XmK76bxtw',
#   'summonerName': 'Ingo Oberhofer',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 243},
#  {'freshBlood': True,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1058,
#   'losses': 319,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'ZarWvqzlcNnZrdWWu4FhJmbPqFPIuE8T7SSBcoy3eNSxS2I',
#   'summonerName': 'BABO AD',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 362},
#  {'freshBlood': True,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1058,
#   'losses': 235,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'eMtzLlKncc3SMDqy40dyzPf6HONWRt2U00U2FLikZDBos6o',
#   'summonerName': 'smile on face',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 275},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1057,
#   'losses': 244,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '4Rv1Bh9eCbJ5f5DElwyCePJYuNg1e6nvD12WZp31TDct9nz1kUUG3yMrnA',
#   'summonerName': 'Τoffe',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 276},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1056,
#   'losses': 290,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'f33EnaSGDW3P2K1RQj4YwDr_vVR9mWcOeNSJcLc6kbQusYM',
#   'summonerName': 'waterenjoyer123',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 342},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1056,
#   'losses': 88,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'F-WoNhiJ4c1kSeaOuho6t4kX7qXb07PhYSjZF2lMdT4frwn49YmZNwiiKg',
#   'summonerName': '25032023e',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 124},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1055,
#   'losses': 341,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'YN7fEn7Nya4tb0Xnx84zBumkU7e8DNzQ1irmMabUMyhzlLpCcIM_DLb5iA',
#   'summonerName': 'Squeezie',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 395},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1055,
#   'losses': 195,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'EBa0UY0bOEYYSEVivoeu3vXx5_GwhyAIHWJxiK3lEPcz16Y',
#   'summonerName': 'chill falls1',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 236},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1054,
#   'losses': 256,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '4SBWp87IwGjtyJ8_PX_rgDGpOZ0YjYOY5bgCYjuuKaM7QX4',
#   'summonerName': 'MVPISQY',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 298},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1053,
#   'losses': 181,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'm6McEhlAWdnGPHwteFHseXsGcpX_8vN9AUL48fRoDZUjfgFS6vWlk1XY_Q',
#   'summonerName': 'mustangGT500',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 223},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1051,
#   'losses': 154,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'fETcSYOrl3khbRID-iyn7otiRfL5yAhPOhp8AghYD9-eJig',
#   'summonerName': 'hellosiemanihao',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 188},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1050,
#   'losses': 278,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'mZxpRWa-h7oI1FbNg4vESEC9QyVUbmpN56DY1-IcLfxfg2zN',
#   'summonerName': 'MHSC FSZ',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 317},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1050,
#   'losses': 185,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'TzZwUgnb5ED6ZZQe1DaZVNScXuhN0SKAo6wNeCjVwZPK-iI',
#   'summonerName': 'Alexxanderkyling',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 223},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1050,
#   'losses': 126,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '0L_GsvvgDireRjDbrjopmfqp1tk3iKfs2mny0qHXRdg5Gnk',
#   'summonerName': 'PaxNoKo',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 164},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1049,
#   'losses': 89,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'lOlwzEtAj9KtHFLPHkEJzYJODjUSpFezRLRSyzqoh0iJv3p8RVqYBU6Tkw',
#   'summonerName': 'goodtoknowyouheh',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 114},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1047,
#   'losses': 298,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'zekb1hyPlhAKXtzasfWXfvh4fLLZolCNPCMOenqrLbI6GwcNQvE3KLylkA',
#   'summonerName': 'Cerecof1',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 339},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1045,
#   'losses': 212,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'ZfpAwAfOE4sSkmK3F2LBqNj3lBklWog4Iw2eTpGzrNkU5NtP',
#   'summonerName': 'Subbex',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 255},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1044,
#   'losses': 99,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'f7KxO4TbumZ4i_-GZ7Cv15v6BhkTFC8xyOL-sHCPXMyvooLyrgMdRJ7ECA',
#   'summonerName': 'Dark Spiderman',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 146},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1043,
#   'losses': 70,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '6UJnRiHM2LNc8IIYPAAvuH-DHmpSr_qD9v23Am1ILXVBdZ4',
#   'summonerName': 'Tentrishious',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 110},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1042,
#   'losses': 251,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'Hecrrq0XgJ6pi4wZHrZQjYycTjiGrMcaORxJfT8fpsrARswpJIw4CDmRSQ',
#   'summonerName': 'V1T Upset',
#   'tier': 'CHALLENGER',
#   'veteran': True,
#   'wins': 293},
#  {'freshBlood': False,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1042,
#   'losses': 168,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': '0THVrgfBCdnBR1fjyTWvXETmiCKcQ_bH5Z-WeIQPsj-PeXXr',
#   'summonerName': 'gigabean',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 214},
#  {'freshBlood': True,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1041,
#   'losses': 402,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'Cc6QXIrMZrgho3avcUEBmBgfLocKGS9XMowCBx6SxPlLceY',
#   'summonerName': 'TTVbigcheektimmy',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 451},
#  {'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1041,
#   'losses': 349,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'PdKVgAfs47INUp5dXV4ywTJHT1oK7tRrQGoHb37lESbEZ_Q',
#   'summonerName': 'head issue1',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 388},
#  {'freshBlood': False,
#   'hotStreak': True,
#   'inactive': False,
#   'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'leaguePoints': 1041,
#   'losses': 220,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'Q1CxOOl4lOFwXednIzDRgK2JJBENzAyCBPVRVt3Y1Fm9u0U',
#   'summonerName': 'REVIENS A KONOHA',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 258}]

# %%
datos
# Out:
# [{'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'J5qBaV6G_yzlkoMmyhdZ8MNMEz_kEGWBsG9NpRPjBweWZfDR',
#   'summonerName': 'NattyNatt',
#   'leaguePoints': 1824,
#   'wins': 626,
#   'losses': 537,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'DgjHY5TXZ2RzAVgBxPv4l3yVurzDMiaPHnytOF4W7rgsH2U',
#   'summonerName': 'Razørk Activoo',
#   'leaguePoints': 1757,
#   'wins': 293,
#   'losses': 211,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'Bz89KoPOnCfJ0XeATw5OY3BRdSeNXpylI5gZiTmX8zzRDTw',
#   'summonerName': 'WOOOLITE',
#   'leaguePoints': 1590,
#   'wins': 413,
#   'losses': 329,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'q8k_YgHmwi6QIsbH7ehmbOeGPgjHyZXQ1xd_SCtzF2juBmyAvhu1lre9MA',
#   'summonerName': 'Stomme Eend',
#   'leaguePoints': 1568,
#   'wins': 235,
#   'losses': 147,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '5XlaL-UN5fE5aoxDTWLZm-XFW_R_-wLbzJQ5fwoUbACdAfNoRyMwCUJnhg',
#   'summonerName': 'frygo',
#   'leaguePoints': 1545,
#   'wins': 465,
#   'losses': 397,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'M1QE7bNdhGGLX3-b7UeOf5NQJXBiGWmfQxC7wHCeI6ZexN0',
#   'summonerName': 'DzuUwU',
#   'leaguePoints': 1531,
#   'wins': 230,
#   'losses': 160,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'uhceFi1O1Dhp7fU0OuaW2xfq3dECuq_FaZh-EI0KPuhmGSo',
#   'summonerName': 'Thumbs Down',
#   'leaguePoints': 1528,
#   'wins': 362,
#   'losses': 287,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '1wQj4s6FES_L7DidngGGRai7pOb7fi_FvRzyVsR3GQO2iGI',
#   'summonerName': 'AHaHaCiK',
#   'leaguePoints': 1527,
#   'wins': 309,
#   'losses': 243,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '9sEEDyB8tEjNsrntAcNpElTqIKNK3aqG5HJZwC08mcjA36o5N8W1B8P_EA',
#   'summonerName': 'Molnigt',
#   'leaguePoints': 1513,
#   'wins': 220,
#   'losses': 164,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '1IGvA60stUNxmmj1nZNecfJ9gfvl7Hn5i76L3Qmch0R049Y',
#   'summonerName': 'Agurin',
#   'leaguePoints': 1510,
#   'wins': 327,
#   'losses': 245,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'kG3BStPT1pyPfFCPwimUqsowGGkq8w_q-H9JN19nOt0jY_437H93RUuJFw',
#   'summonerName': 'FUR Ayu',
#   'leaguePoints': 1507,
#   'wins': 138,
#   'losses': 60,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'n3VP5OBXpAKjmZD3AqDYyp45RCgOfHf4LPVnLjbE0pR7_xGd',
#   'summonerName': 'KC NEXT ADKING',
#   'leaguePoints': 1495,
#   'wins': 415,
#   'losses': 335,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'O4a68AGyiMbSHFWL-KFv6lIt0OfQWvI70xIYuuAQ6A0tSEo',
#   'summonerName': 'Lekcyc',
#   'leaguePoints': 1486,
#   'wins': 156,
#   'losses': 99,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'G1Rn7mTzHL9-089SxUSq_K62ZPnsQCVOQiWbPSuXPJbMs54',
#   'summonerName': 'Kieran Tierney',
#   'leaguePoints': 1455,
#   'wins': 172,
#   'losses': 110,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'bP9AljOVJIHe77pwmy8Om34sYNWg8ncb_NCOakN1SwcLbyY',
#   'summonerName': 'TakeSet sama',
#   'leaguePoints': 1438,
#   'wins': 274,
#   'losses': 217,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'CjbfXjh9qiBLxPjaGFkak-ut-jTMrK8o7YiXIGWpz1_TAxM',
#   'summonerName': 'Odysseus131',
#   'leaguePoints': 1409,
#   'wins': 369,
#   'losses': 304,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'ryLV40Fsl9-zEh1iHnGCeKx1muk5tIAMMXFt_YP0RK3_yVDQr5jqhCN-Yw',
#   'summonerName': 'its not over',
#   'leaguePoints': 1397,
#   'wins': 181,
#   'losses': 119,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'dunSZOsk5xFb79u8cyFW0RBK7UUJXkeNzGNpaUaADaZJhoA',
#   'summonerName': 'XZX',
#   'leaguePoints': 1380,
#   'wins': 297,
#   'losses': 231,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'F5wgvQR10q6gk8ZJQvqIs3MX1O2erasFfwjIB_UCAG9VDy4',
#   'summonerName': 'the inescapable',
#   'leaguePoints': 1377,
#   'wins': 357,
#   'losses': 280,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '7i2wlU4gsM2BZvjdwTpZpH8RwNsmwca5vKhqQSSOa2NQU3w',
#   'summonerName': 'GO toucouille',
#   'leaguePoints': 1361,
#   'wins': 309,
#   'losses': 255,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'ApLMzo1xUXConLa9LqNbxRJZjvRjyY7c4qPhYZ3qrEciSRw4V_oS5v1zVg',
#   'summonerName': 'Thomas Shelby2',
#   'leaguePoints': 1342,
#   'wins': 337,
#   'losses': 270,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'RQORgwxq88JggtQyReJh6dLP2sWhSF7PQWXDt6Wz98PSAJE',
#   'summonerName': 'Sir Leywin',
#   'leaguePoints': 1341,
#   'wins': 253,
#   'losses': 195,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'q1QCkC0X4N3A0pP3Db933xWeVWFF3CAKZoOG0pdKMuuxda8',
#   'summonerName': 'Peng04',
#   'leaguePoints': 1335,
#   'wins': 181,
#   'losses': 137,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'HAh2KqYvmWmteFmVH4RYOm_ezxELp0qZ7w-RMK-ZIY7Ny3o',
#   'summonerName': 'OSCAR MUÑOZ',
#   'leaguePoints': 1328,
#   'wins': 335,
#   'losses': 276,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'xiYxjPXMtKEmIvZ1QzqzAiUbtRPCD2_atF82NdpeDocNRMU0secidpeEjA',
#   'summonerName': 'sanghyxxn',
#   'leaguePoints': 1327,
#   'wins': 423,
#   'losses': 341,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '5EJHYXpFe9XN5EaKOQfrRiAMh0aHOKq4csq_HDc3Swr2DtE',
#   'summonerName': 'XL PJ',
#   'leaguePoints': 1326,
#   'wins': 349,
#   'losses': 282,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'tLtzG0VteMuGTUqhJsHKOjGhBewYHajdT8AWpZki_wK-qL8',
#   'summonerName': 'Grizzły Hills',
#   'leaguePoints': 1304,
#   'wins': 415,
#   'losses': 360,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '1rDh335JP8Vq7WSQPKQTp2VkAao9uXsz6V_bIu7jtIt93G3_',
#   'summonerName': 'xLinayaa',
#   'leaguePoints': 1302,
#   'wins': 159,
#   'losses': 100,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'd_3yYK0e_uJYLtvi7VgWTxd5qTa1aQkjr_3V6GE2nG8RyV0',
#   'summonerName': 'Me Wo Akeru',
#   'leaguePoints': 1301,
#   'wins': 283,
#   'losses': 237,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'PYk5xEhl7qLFDAMv0XpHrKE3pvfOjhYznls2st--YBuny34',
#   'summonerName': 'M1dLaoban',
#   'leaguePoints': 1289,
#   'wins': 533,
#   'losses': 473,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'Qq9l2gfPQNzDLSg1pwe9tZbNYQTTMlrO8EM2oDprJ8H15Ao',
#   'summonerName': 'twtv habuubu',
#   'leaguePoints': 1285,
#   'wins': 445,
#   'losses': 382,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'pcRrrwtnVsAwgoQkCpCJggeTu6yxj-gIK9MJi4_UALzne6M',
#   'summonerName': 'AbbedaggÆ',
#   'leaguePoints': 1281,
#   'wins': 186,
#   'losses': 141,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'rQziWbPPxrOvp115RJdAYReFxve61Cuq0QwwZLkEYnDvEuls',
#   'summonerName': 'METROOOOOOOOO',
#   'leaguePoints': 1273,
#   'wins': 469,
#   'losses': 405,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'BfSea6ghOB4lN_VxFwSiiCqyHapY2i7LUjT-YlY7GgNAJOA',
#   'summonerName': 'G2 Joker',
#   'leaguePoints': 1271,
#   'wins': 562,
#   'losses': 487,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'YzyFT0b2KuzjadiZqTy0cEKBGV0GKWoyFylQhmnf2AQFyM8',
#   'summonerName': 'Dzu',
#   'leaguePoints': 1265,
#   'wins': 340,
#   'losses': 300,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '8IZkJceaIpeDWTFi3ZcKlzpbZcyN7_N6-rTpHocDT4dWLkU',
#   'summonerName': 'shenxian23',
#   'leaguePoints': 1264,
#   'wins': 563,
#   'losses': 510,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '64gFPiZSq3wbubKsJ82ILBNWVwpsvptP-LPskJLkszTYf32okLhkHcCltA',
#   'summonerName': 'Yuuri Leo',
#   'leaguePoints': 1263,
#   'wins': 318,
#   'losses': 270,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'X00YHs7gUsJpY_aMWlZWhuhaK_cpYPyaA083R3O9VHJvifU',
#   'summonerName': '15th July',
#   'leaguePoints': 1261,
#   'wins': 472,
#   'losses': 415,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'gEjtXIZJBpxp0SSS-_ZpJbCGO_saYavtAjMrXx4zrEZ_Olnykxi4V3K6mw',
#   'summonerName': 'Mαster Oogwαy',
#   'leaguePoints': 1256,
#   'wins': 208,
#   'losses': 158,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'x6hKmIy4EPbGvendWl7QgO2T_MA3O3dTBd-Y80lCMI9KBYnmv8W4OVBuIA',
#   'summonerName': 'choosetosmile7',
#   'leaguePoints': 1254,
#   'wins': 139,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'UCExV4Tvycu0vOwOgZ9fPO3EWbYovofAUp7ZxYtl4jrvlz4',
#   'summonerName': 'qwqw',
#   'leaguePoints': 1253,
#   'wins': 789,
#   'losses': 721,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'KdV4P0zyBuDT4bM0JlL6Q66fD5sNzMvNoa3xPdDKWqyYdExIlstdeBZWog',
#   'summonerName': 'SPOLFCEI',
#   'leaguePoints': 1253,
#   'wins': 446,
#   'losses': 389,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'nNEhsbqNSvn_BWiKKLTAHnvLQo7Ye5VskjHSHDcS3fpzjOJy',
#   'summonerName': 'TwTv Kaos Angel',
#   'leaguePoints': 1253,
#   'wins': 264,
#   'losses': 215,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '3oMV_ASvwmVB_9-TmsDlueCoVeJaYf-FmkXNqNpIbyrCpC0',
#   'summonerName': 'Isagi Žnjoichi',
#   'leaguePoints': 1252,
#   'wins': 203,
#   'losses': 155,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'Dhjh-PLXhMXkYPwSHSimPQQWOzlsFnONq-z5VNR-QTiBlas',
#   'summonerName': 'Wataru Endo',
#   'leaguePoints': 1246,
#   'wins': 116,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'kTaTQfq3WJYH2MrNu-1wTQnGpeY0TjzLNHCVGItM-ZlHqKU',
#   'summonerName': 'zeus manchego',
#   'leaguePoints': 1239,
#   'wins': 307,
#   'losses': 255,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'R1ApS6Ci1NHEfYKutO4PW8WH3RNtXk0bycQHrnseJQ2JWzLB',
#   'summonerName': 'hovinko z kose',
#   'leaguePoints': 1235,
#   'wins': 361,
#   'losses': 322,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'l1ZqFoFf2vX-Wm8RNEnEh21pl6NlxOvOw6xXt9LWEceCARnV',
#   'summonerName': 'Mountain Wolf',
#   'leaguePoints': 1234,
#   'wins': 171,
#   'losses': 134,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '8Q-m0Q_H0gl4Sfe6QOVV3A3ZOV4sfk8vekCBrJ6YnlivMrE',
#   'summonerName': 'worst sona world',
#   'leaguePoints': 1230,
#   'wins': 161,
#   'losses': 108,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'QbBGkZwSmCR6ktps9pAa5vBYRxdmydvYDNj0LjdEc4Jbaac',
#   'summonerName': 'Stack Collector',
#   'leaguePoints': 1229,
#   'wins': 187,
#   'losses': 137,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'cAtRWbi9oA3c3S2aOCMc47KqxzQuXAEykv1cyAQKKWAwS-_8kKhcg6TrJw',
#   'summonerName': 'sdfsdfsgert',
#   'leaguePoints': 1228,
#   'wins': 271,
#   'losses': 214,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'pkhWQ_RxjoAM8I_v81JSYgp-d62hdtc4lN-hSxM_-_qwbFAT',
#   'summonerName': 'ANDARlEL',
#   'leaguePoints': 1225,
#   'wins': 228,
#   'losses': 183,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'S8JX7JQsJuPLDAv--ZM604E0RX7HIdNr8gaztxv9yUpWVug',
#   'summonerName': 'FUN k3y',
#   'leaguePoints': 1221,
#   'wins': 188,
#   'losses': 138,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'aHTjzCje-TnFMWIF5uNkZRYPhkvikWTjVlSgt93Y-2FAgbk',
#   'summonerName': 'Boukada',
#   'leaguePoints': 1219,
#   'wins': 164,
#   'losses': 118,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'Cbaz3NNvVAsXhGMPjZ2sbxUedCL8m68DWYrdL_j9cVUyGTaC',
#   'summonerName': 'Worst Zac EUW',
#   'leaguePoints': 1218,
#   'wins': 150,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'UdCySNnu4GjA8CKOVGWufnvIkQSt1UMynDKhdj4-Iul4K5E',
#   'summonerName': 'TwTVxKenzuke',
#   'leaguePoints': 1214,
#   'wins': 447,
#   'losses': 404,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'nC_9B_j6Xp3pSpuUCtmwVtovVXXVD8h-7wFq5SV2-hKS-fw',
#   'summonerName': 'pocovirtuoso',
#   'leaguePoints': 1214,
#   'wins': 271,
#   'losses': 226,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'd3uZTwVJjoxi63wOGuJPm6ZzR-KjbMEldlbfaN0YCumjvoHm553hbi6R5A',
#   'summonerName': 'TheShy offspring',
#   'leaguePoints': 1210,
#   'wins': 328,
#   'losses': 276,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '_I4pTvSqFuwD_xxlOEn0_tuz3FsgW8rtsFlUbLQtuZInxA-GRX_KZB4EMQ',
#   'summonerName': 'Reborn Berkan',
#   'leaguePoints': 1206,
#   'wins': 215,
#   'losses': 155,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '9IGZBrILipePym_tx63jvvTewuFtRlkFdO_hdE6fUvtGctI',
#   'summonerName': 'f3ed l0rd',
#   'leaguePoints': 1205,
#   'wins': 146,
#   'losses': 101,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'HHUCxKLtEhkn1jh4Gly5CxtnsCvjdTkdqCwrFDrWYsf9G7t3LWC9MSVRTA',
#   'summonerName': 'Subgainer700',
#   'leaguePoints': 1204,
#   'wins': 301,
#   'losses': 236,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '0AxsaPs89BlcdV-khyMNSgpw27GLMpkWyJhis2z_Op_uVxUD',
#   'summonerName': 'Hyweedri',
#   'leaguePoints': 1204,
#   'wins': 151,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'vab6AZlVZWRKw7O_s74JbQr0cmWgqr3S4YAlNvZZiy79OznoAPHvYkaQpw',
#   'summonerName': 'I Love Uber Eats',
#   'leaguePoints': 1203,
#   'wins': 423,
#   'losses': 379,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'HUhKpXIs5v59pPWxM0j3zhxNk_a9vYMURg7UQWk_grXwBsHRl1YrTBVdcw',
#   'summonerName': 'månebarn',
#   'leaguePoints': 1201,
#   'wins': 215,
#   'losses': 122,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'BNEDV9nK1xR2_DGvfvAqruXgqXMWKdi7vSVKKi_yxMQzcr0I04XwEsNLmQ',
#   'summonerName': 'Kimchi SUP',
#   'leaguePoints': 1200,
#   'wins': 434,
#   'losses': 360,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'TxvIYYvEW7gIvYsRB_vHpw-2q4FqckhO7UaRUZmJKrM4mpo',
#   'summonerName': 'Experiment 604',
#   'leaguePoints': 1199,
#   'wins': 473,
#   'losses': 422,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'NNPVPAEq5PZHcfNYdxInjJPw8_eqht4KBpn_3FfYY1V7plQ',
#   'summonerName': 'sootrebor',
#   'leaguePoints': 1199,
#   'wins': 239,
#   'losses': 186,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'sC-7Hlg8BPI7iUCURdKbhY_RYdjBXR4txa6CPBWVuRN-Y_pM485iCGVCuA',
#   'summonerName': 'TwitchTv Zy0xxx',
#   'leaguePoints': 1198,
#   'wins': 238,
#   'losses': 160,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'w7wyU3YkQTpdlRw-w2tfHME8-HoZMQlj1mkLZLjg90G_Z7o',
#   'summonerName': 'Dragdar',
#   'leaguePoints': 1196,
#   'wins': 242,
#   'losses': 196,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'mbF3Q5F3MUmzOjxrDZ9o5xbfsnh2ewwJQTNC4BSz-oTIG3o',
#   'summonerName': 'PatkicaA',
#   'leaguePoints': 1196,
#   'wins': 168,
#   'losses': 122,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'qUoSchMm3lwuNjsVyggsAciyDs_9S7tKi1divx-6SCBbnznHrW6GgLRgMg',
#   'summonerName': 'asdcxc',
#   'leaguePoints': 1193,
#   'wins': 116,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '1PwKFSMqifytuG7dbLRUjh8ubWXXu3CQPN_qPrZOxqbVpYIb',
#   'summonerName': 'TTV H0rnlime',
#   'leaguePoints': 1190,
#   'wins': 559,
#   'losses': 506,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'nJqVNJ7UgNv80-jY-smrLa-UD4uZPmBdD0F4s0un9iV1edc',
#   'summonerName': 'DizL1',
#   'leaguePoints': 1188,
#   'wins': 317,
#   'losses': 267,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'tj_OszD5yhDCpPmjv_njOLI-JBatcG_GFJuMqS_XJAcs3aLG',
#   'summonerName': 'Pusi Puu',
#   'leaguePoints': 1184,
#   'wins': 300,
#   'losses': 249,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'gXAvRKWTJOCfrRdEQQvyN-kPlCgFbX8PZhkyQyt6Bls_adj74IwLFtY4EQ',
#   'summonerName': 'Anothertomb',
#   'leaguePoints': 1182,
#   'wins': 133,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 't8WNmtEhAD20QIs4l5Ao1_dNnQ677EQO6pWum_3N8c2eWV_I40aBKJrllw',
#   'summonerName': 'Photon1',
#   'leaguePoints': 1181,
#   'wins': 347,
#   'losses': 290,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'I3PWE-1KL3yiAQC4zom9W9n4gyPIvfTt1VfQzhq0haXrPjs',
#   'summonerName': 'Crowno',
#   'leaguePoints': 1180,
#   'wins': 404,
#   'losses': 356,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'Thf095zID37t7kFgd8-KogjIStSlU2Q2AnTc1K_XDfxOALxS',
#   'summonerName': 'Drututt',
#   'leaguePoints': 1179,
#   'wins': 212,
#   'losses': 168,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'ZJCYwtZjuGR_jspWdjh5Q75k_2SSxBNrk8qc7Rro_ondVd9p',
#   'summonerName': 'zhypey',
#   'leaguePoints': 1178,
#   'wins': 128,
#   'losses': 94,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'p1v307T_wG8lQro_TFrDNANKMOt6_4jnT6gJ-QuMs0221Eo',
#   'summonerName': 'Jαvier',
#   'leaguePoints': 1176,
#   'wins': 279,
#   'losses': 234,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'K1YfJ-LbayabC-uyNCvq_2ldXO9bkW9DM6myKexj4Eua5eI',
#   'summonerName': 'Veignorem',
#   'leaguePoints': 1171,
#   'wins': 271,
#   'losses': 233,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'd8QMvH0y4j-aoFf9ha0iij7yvU_-WBVey2bCYhhMeHsir7SY',
#   'summonerName': 'Heroic Miracle',
#   'leaguePoints': 1171,
#   'wins': 161,
#   'losses': 97,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'cU542jI7fcZzq2T00FnQoN_RiRoy_Pl8k2zN0wbBVVC9aNQ',
#   'summonerName': 'WP GG XD',
#   'leaguePoints': 1170,
#   'wins': 287,
#   'losses': 245,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'e83PBz08Vw13ys8qSoxHX3U8-eESqJWHRpClPwjCJP_FS5UhwkdlHdjiMA',
#   'summonerName': 'Being left',
#   'leaguePoints': 1168,
#   'wins': 233,
#   'losses': 171,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'rjWwaRK55lhfA1shsYGgziRWaZW1i5muT2OpBXl2XFoUkNpj',
#   'summonerName': 'Sebekx',
#   'leaguePoints': 1168,
#   'wins': 212,
#   'losses': 166,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'IziR2eGQfo3tUSMBD0vD_GA5zMdzOaBk2lqopVL54T-s1zkz9hbQCiCSIw',
#   'summonerName': 'Ice0713',
#   'leaguePoints': 1168,
#   'wins': 148,
#   'losses': 78,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'bCG3vX6TRljvtodIfWMtbBWp-LESs1DOdbY6yhCH3WB0c0T_XHVZEw10EQ',
#   'summonerName': 'ImJustAKid17',
#   'leaguePoints': 1165,
#   'wins': 133,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '21D3Y5qKSktkd7agdIZAdBPbvj7CRIO7A4-QU3Qj6UeSCU-J',
#   'summonerName': 'G2 Susamaru',
#   'leaguePoints': 1163,
#   'wins': 360,
#   'losses': 313,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'F6KzktSmyJ-ArawxnEC3TlTx3rJVGQeqQj3y4gTSPAydRpo',
#   'summonerName': 'GW Villager',
#   'leaguePoints': 1163,
#   'wins': 285,
#   'losses': 235,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'FGG6RgHUYMtUi5kQraVG9m1G09q1xH4kvz0qJ6C2_As8aIA',
#   'summonerName': 'Schuhbart',
#   'leaguePoints': 1161,
#   'wins': 180,
#   'losses': 131,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '3SbkJk-qRVVXvM3Vs50EcDus8mNoZjNvSS-z5BJhkmHf1EJ1',
#   'summonerName': 'Groot L9',
#   'leaguePoints': 1159,
#   'wins': 627,
#   'losses': 587,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'gvSUWX2o4eGzIDAyPnrmp-vyR0g7f2s4QfU4Y1o1nT090pg',
#   'summonerName': 'dajor25',
#   'leaguePoints': 1158,
#   'wins': 415,
#   'losses': 356,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '4tieSjF7k-VSq0jGnVapaoxHe9yJ6hA_uYAj0DykVejmQ28hmb_DShYlZQ',
#   'summonerName': 'TTV suki545',
#   'leaguePoints': 1155,
#   'wins': 175,
#   'losses': 132,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'daY16czGgIUieVJFYYt15gmyyJp5W0uKrbdYWTf8PXkubmLV',
#   'summonerName': 'K405 N815',
#   'leaguePoints': 1152,
#   'wins': 188,
#   'losses': 133,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'ShbaCafTci354lvbhgKo9X_Hus2GsMnQzTMUgYTOqEye7MAius6sUo0brA',
#   'summonerName': 'goodtoknowyouhah',
#   'leaguePoints': 1152,
#   'wins': 108,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '9U-dXnaYV7wwOdeR7K3bO4PTE2bUqu4iFxrDk32UDpFmXug',
#   'summonerName': 'artistic turtle',
#   'leaguePoints': 1150,
#   'wins': 271,
#   'losses': 227,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'm5-vnpRwqwATAAu8M81uWsSqfmKhxDnfWn5-mttgbqEBEAU',
#   'summonerName': 'Nomi',
#   'leaguePoints': 1149,
#   'wins': 304,
#   'losses': 245,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'qpE5_SAMkfIvWeP5cwnzG7rNfR9uRwLUxtPW_hPlygyCo-Y',
#   'summonerName': 'Porsche Kaymin S',
#   'leaguePoints': 1147,
#   'wins': 221,
#   'losses': 183,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'ZkuQL4DYDUwNpAYXjllzU_RSQjekliOg-JulDCFzOq87bfo',
#   'summonerName': 'i can fight',
#   'leaguePoints': 1144,
#   'wins': 558,
#   'losses': 500,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'K0b5qgt2u-sAhRzDH5XlDHBtCk0Szxeg31M3sKVi5NK_YtM',
#   'summonerName': 'DONATELL0',
#   'leaguePoints': 1144,
#   'wins': 283,
#   'losses': 239,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '6PjQq_S3Fs325AQ_-X3Zkab_qSSRLwJTKlyDPOj4Frv9Tk0',
#   'summonerName': 'Maynter',
#   'leaguePoints': 1142,
#   'wins': 220,
#   'losses': 180,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '7ntRBlpECrvOZEtz9p7XZT5KdAfuWVDOVx-xnZGNBimnP_Y',
#   'summonerName': 'C9 Veigar V2',
#   'leaguePoints': 1140,
#   'wins': 163,
#   'losses': 116,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'pN4frG5_HJg6WTQfspA1UKPttgbDzFGLNmRNZgwLO4WNvsQ',
#   'summonerName': 'Sebeks',
#   'leaguePoints': 1138,
#   'wins': 206,
#   'losses': 160,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '-oIGHPekpDQfsBh8XH1VPEUztFk-sXAfhUCGMmSb6QaScZU',
#   'summonerName': 'ayekasia',
#   'leaguePoints': 1133,
#   'wins': 189,
#   'losses': 147,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '3zIuLbxNyBCCHVBDTe4hLyAS3nuvxo-RyN2aSQ3M9VguPNY',
#   'summonerName': 'Guillermo Gombao',
#   'leaguePoints': 1132,
#   'wins': 401,
#   'losses': 349,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'j4mqDfYQeGt5bvOXDJFrRNOCuD2VTm8YXRIRjW-2m-5MOOs1wmI_pRBAOw',
#   'summonerName': 'GarbageTrashLane',
#   'leaguePoints': 1132,
#   'wins': 300,
#   'losses': 246,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'NU6W3rBtBr2qnMwzOnIne0g5j6x_rkBDCIcKJaY8uGTVgeA',
#   'summonerName': 'IWILLC0NQUER',
#   'leaguePoints': 1130,
#   'wins': 560,
#   'losses': 504,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'tx-mei4UFJkMhPSJThki3d1HeTAUWCEToGyZwYW56qGgyJS8rK-2ueBJtw',
#   'summonerName': 'AgnwstosPente',
#   'leaguePoints': 1130,
#   'wins': 282,
#   'losses': 227,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'VDccKKiffl7aY8GE9eCQHVoXaC4lehCUQ2CVhDVOyhSVaok',
#   'summonerName': 'INT Baul',
#   'leaguePoints': 1130,
#   'wins': 170,
#   'losses': 118,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'ri4ZyziQf-uaEDXPa-sOVx0ihAqq0sx3Hos3OeqYWrtxyjhToPUatXyaag',
#   'summonerName': 'u good me better',
#   'leaguePoints': 1130,
#   'wins': 153,
#   'losses': 110,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'OdU7Dga3y_YpXUc1sZ_QgUd3iZtmpGXH_mBjXbKRf0-8lc0',
#   'summonerName': 'messi sup acc',
#   'leaguePoints': 1129,
#   'wins': 392,
#   'losses': 351,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'dtCYU211crNySuMfNG-E62FquFfB6CbQKiX8vpJlm0KO_2M',
#   'summonerName': 'Xicor7',
#   'leaguePoints': 1127,
#   'wins': 226,
#   'losses': 177,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'TFNly98JiRZgdgZdz6bIZR8W43iM2We0SIh10K8buFWP-Lg',
#   'summonerName': 'sharynne enjoyer',
#   'leaguePoints': 1126,
#   'wins': 508,
#   'losses': 467,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'uHz29LMxJ1JI9-Z4LETiftPPBL-2urIr90LER98Dbf3HdoGs',
#   'summonerName': 'name change luck',
#   'leaguePoints': 1123,
#   'wins': 185,
#   'losses': 127,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'yu0LnGpQpuBQQfkFdW-9n0Nr_bGe1Dh-ElZ-2S1srA2pPws',
#   'summonerName': 'Roulette',
#   'leaguePoints': 1122,
#   'wins': 614,
#   'losses': 558,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'yJQvdXHC3ClLX8638xApQXGM5vrLLfJrsn_4WofbssbWGPk',
#   'summonerName': 'BDS xMatty',
#   'leaguePoints': 1121,
#   'wins': 363,
#   'losses': 308,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'DXn-t6qLssmYI_6I7U0PQrwUVAzdHHs4LpTH7rFnwYZA-PyhrAVzIgpohQ',
#   'summonerName': 'LEC ADC 2024',
#   'leaguePoints': 1120,
#   'wins': 339,
#   'losses': 292,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'hus0-mmSbnaJ2VYncFEChcE2M2-LNeI2--qwgV7p9YKsmGjJFMV8BB2XLA',
#   'summonerName': 'Ziqmo0',
#   'leaguePoints': 1120,
#   'wins': 177,
#   'losses': 134,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'D7-ZkJRNeHxDJpj4zS0-fs_vax1M--WyFn4CJV17brWJuvQ',
#   'summonerName': 'CookieHub Diff',
#   'leaguePoints': 1119,
#   'wins': 131,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'uZj5Y2H-J6xuEwSh2sxfoVw4GR2Z2BxR6N0lF0S_AhOS4d4',
#   'summonerName': 'N1ghtingäle',
#   'leaguePoints': 1119,
#   'wins': 74,
#   'losses': 39,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'AWabAuX737TdLcRNhJtcNYuMHDBwgCCp90RZbWFjlNWci7s6',
#   'summonerName': 'SLT 2',
#   'leaguePoints': 1118,
#   'wins': 267,
#   'losses': 221,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'LJwVPFpdDBLXXXkN-DDO-op2J68mKsjKce2MlxYlhtSbQLU',
#   'summonerName': 'Delitto',
#   'leaguePoints': 1116,
#   'wins': 209,
#   'losses': 167,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'jfCUz_uRqTfF329ySHyJpZu5foP3A2la9zD6R3uo0KMz2i0',
#   'summonerName': 'Heavenly Scars',
#   'leaguePoints': 1113,
#   'wins': 300,
#   'losses': 253,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'o5LL7mtAe8P2ERf5Eo1Xm1-gtxfX8tLiIoFmhm40Nz2WRgQ',
#   'summonerName': 'WindLoL',
#   'leaguePoints': 1110,
#   'wins': 293,
#   'losses': 252,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'W-iSfH6J15uKm2JSYF2wr9x4zHDTZyJFrImKDvRSw3Ma3BQ',
#   'summonerName': 'Worten Sempre',
#   'leaguePoints': 1107,
#   'wins': 327,
#   'losses': 275,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'zVvCDLgtY-lXB9ooCSKWqEIUqfe72b_lSiCtBy3lHUipQGQ',
#   'summonerName': 'Odoamne',
#   'leaguePoints': 1107,
#   'wins': 237,
#   'losses': 199,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'YL0zND8ArYuBelJDoVY633iJTPE0DrTj3EJwU2dJ2niZC3dx',
#   'summonerName': 'zrh2',
#   'leaguePoints': 1106,
#   'wins': 317,
#   'losses': 270,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'UgLvw4mpnO0FShYAgCB37hCKbj4ZoUfPhRj-OiJJfVYMMva5LWhskWbMxw',
#   'summonerName': 'Anathemas',
#   'leaguePoints': 1106,
#   'wins': 210,
#   'losses': 141,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'QZtgWwM9mF9HtAoE7R1zPk6_lTIIbfBYghqhCIOQ7QvXcWChOAdBFavGTw',
#   'summonerName': 'Noeyim',
#   'leaguePoints': 1106,
#   'wins': 168,
#   'losses': 108,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
# ...
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'fEpWy-7KY5Iabk0xEuQb650ShqHzuvxr3tSejqLjSSZLRbA',
#   'summonerName': 'ÂDC2k17',
#   'leaguePoints': 1079,
#   'wins': 99,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'DC7oncmAlDWjXHEPk3Klj98MUVBoSyAaBa7Z2xVqdjLn_S4f',
#   'summonerName': 'GAREN256',
#   'leaguePoints': 1078,
#   'wins': 164,
#   'losses': 127,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '2KhvUuaZvfo-I_zXTueFYMtIzaMnsjs1Q3IR2Wzqg6RAans',
#   'summonerName': 'MDB top acc',
#   'leaguePoints': 1076,
#   'wins': 440,
#   'losses': 393,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'I8QYiBnyS8dgXe-cW0uCNlsPh7pBClNeFg7ImB0hpj21wmsudlTluV08hw',
#   'summonerName': '2023 SOLDIER',
#   'leaguePoints': 1076,
#   'wins': 308,
#   'losses': 272,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'cGLOpD7S0SIWpqcGNUku2VIksErnm2H_fq2of3Dbfymsi1U',
#   'summonerName': 'Wesley Warren Jr',
#   'leaguePoints': 1073,
#   'wins': 467,
#   'losses': 414,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'yKts24kvQ4DnVlW_TLJCWKdTaPopbm54iikYexOU2hG4VrnT',
#   'summonerName': 'RhiIech',
#   'leaguePoints': 1071,
#   'wins': 453,
#   'losses': 409,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'C_qkNx0u0ypBDEZIztyIrKWaLaR8RnEpFZISaJHleX-nsq0',
#   'summonerName': 'TheRoyalKanin',
#   'leaguePoints': 1070,
#   'wins': 576,
#   'losses': 532,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '6Zsm6NMwOIcYGmxOt-8GNEJkxYrmVZTR7rLeuLa_5wXvK9M',
#   'summonerName': 'ni pitié ni rien',
#   'leaguePoints': 1069,
#   'wins': 288,
#   'losses': 210,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '-7R7SSuhyNspzq7FlZ_r0HCbvF9ETHThLYCH6S39HIztMHZI',
#   'summonerName': '113 777',
#   'leaguePoints': 1069,
#   'wins': 241,
#   'losses': 184,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'VYg7rjXYoQbLKIEfz7PaclfAIF_hHFSF89XqCAlCZKh9KH0So0j5iVPRgQ',
#   'summonerName': 'haplarimi aldim',
#   'leaguePoints': 1069,
#   'wins': 198,
#   'losses': 140,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '1ofzSgm9mjVxO1IUxa46t4iPyCZXxXQCzJWtdl2YJg5snH4',
#   'summonerName': 'Shαwn Frost',
#   'leaguePoints': 1069,
#   'wins': 134,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'hROOijgJFYRuPcrQihWAt-407zbQyEx_06jnGvrLkkyAJmrE5EuIMXJyfA',
#   'summonerName': 'Groinze',
#   'leaguePoints': 1068,
#   'wins': 219,
#   'losses': 181,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'mhrWR0kK_JsaazB7lIHTHGqBafgjJ5vaRGtTkroTadhi_W5h',
#   'summonerName': 'NIKOLA JOKIĆ',
#   'leaguePoints': 1067,
#   'wins': 189,
#   'losses': 142,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'z_Ox4s5SQ27OH-QyYq1WAxFRODNuPFvW2G8RxVikeZIveH8',
#   'summonerName': 'Rell Pyke OTP',
#   'leaguePoints': 1067,
#   'wins': 177,
#   'losses': 140,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'iv0Z9Peuxu-h1Ni5o9gAaaS56MfS3Gi-vZDO65biGom-gUM',
#   'summonerName': 'NEVER WEAK AGAIN',
#   'leaguePoints': 1066,
#   'wins': 269,
#   'losses': 235,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '5x-CfXYho8uu5I7WB-ArXJoXcN4n8wOngfavGdXwgvxzFE7y',
#   'summonerName': 'Riven PhD',
#   'leaguePoints': 1063,
#   'wins': 217,
#   'losses': 161,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'kNJgiJt_CqZsrv3vbCAerkK5g5Bmuiya2vzAooVaHCMCy6w',
#   'summonerName': 'TTV Potent213',
#   'leaguePoints': 1062,
#   'wins': 370,
#   'losses': 320,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '_pRruSITpetlhIw_hKon0eQa3uaEzdgnTQQ_Du7OyCuXpvk',
#   'summonerName': 'B Ζ',
#   'leaguePoints': 1060,
#   'wins': 516,
#   'losses': 476,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'zvtu60jDg1ng72wYmRAD4mwG8sjWXn1WF3OzwWrjvM0VEvc',
#   'summonerName': 'den store mand',
#   'leaguePoints': 1060,
#   'wins': 262,
#   'losses': 220,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'G838-53rNkJ0ZISeof1IEcn250QV4fLhbZRkL4XmK76bxtw',
#   'summonerName': 'Ingo Oberhofer',
#   'leaguePoints': 1060,
#   'wins': 243,
#   'losses': 197,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'ZarWvqzlcNnZrdWWu4FhJmbPqFPIuE8T7SSBcoy3eNSxS2I',
#   'summonerName': 'BABO AD',
#   'leaguePoints': 1058,
#   'wins': 362,
#   'losses': 319,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'eMtzLlKncc3SMDqy40dyzPf6HONWRt2U00U2FLikZDBos6o',
#   'summonerName': 'smile on face',
#   'leaguePoints': 1058,
#   'wins': 275,
#   'losses': 235,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '4Rv1Bh9eCbJ5f5DElwyCePJYuNg1e6nvD12WZp31TDct9nz1kUUG3yMrnA',
#   'summonerName': 'Τoffe',
#   'leaguePoints': 1057,
#   'wins': 276,
#   'losses': 244,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'f33EnaSGDW3P2K1RQj4YwDr_vVR9mWcOeNSJcLc6kbQusYM',
#   'summonerName': 'waterenjoyer123',
#   'leaguePoints': 1056,
#   'wins': 342,
#   'losses': 290,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'F-WoNhiJ4c1kSeaOuho6t4kX7qXb07PhYSjZF2lMdT4frwn49YmZNwiiKg',
#   'summonerName': '25032023e',
#   'leaguePoints': 1056,
#   'wins': 124,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'YN7fEn7Nya4tb0Xnx84zBumkU7e8DNzQ1irmMabUMyhzlLpCcIM_DLb5iA',
#   'summonerName': 'Squeezie',
#   'leaguePoints': 1055,
#   'wins': 395,
#   'losses': 341,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'EBa0UY0bOEYYSEVivoeu3vXx5_GwhyAIHWJxiK3lEPcz16Y',
#   'summonerName': 'chill falls1',
#   'leaguePoints': 1055,
#   'wins': 236,
#   'losses': 195,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '4SBWp87IwGjtyJ8_PX_rgDGpOZ0YjYOY5bgCYjuuKaM7QX4',
#   'summonerName': 'MVPISQY',
#   'leaguePoints': 1054,
#   'wins': 298,
#   'losses': 256,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'm6McEhlAWdnGPHwteFHseXsGcpX_8vN9AUL48fRoDZUjfgFS6vWlk1XY_Q',
#   'summonerName': 'mustangGT500',
#   'leaguePoints': 1053,
#   'wins': 223,
#   'losses': 181,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'fETcSYOrl3khbRID-iyn7otiRfL5yAhPOhp8AghYD9-eJig',
#   'summonerName': 'hellosiemanihao',
#   'leaguePoints': 1051,
#   'wins': 188,
#   'losses': 154,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'mZxpRWa-h7oI1FbNg4vESEC9QyVUbmpN56DY1-IcLfxfg2zN',
#   'summonerName': 'MHSC FSZ',
#   'leaguePoints': 1050,
#   'wins': 317,
#   'losses': 278,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'TzZwUgnb5ED6ZZQe1DaZVNScXuhN0SKAo6wNeCjVwZPK-iI',
#   'summonerName': 'Alexxanderkyling',
#   'leaguePoints': 1050,
#   'wins': 223,
#   'losses': 185,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '0L_GsvvgDireRjDbrjopmfqp1tk3iKfs2mny0qHXRdg5Gnk',
#   'summonerName': 'PaxNoKo',
#   'leaguePoints': 1050,
#   'wins': 164,
#   'losses': 126,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'lOlwzEtAj9KtHFLPHkEJzYJODjUSpFezRLRSyzqoh0iJv3p8RVqYBU6Tkw',
#   'summonerName': 'goodtoknowyouheh',
#   'leaguePoints': 1049,
#   'wins': 114,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'zekb1hyPlhAKXtzasfWXfvh4fLLZolCNPCMOenqrLbI6GwcNQvE3KLylkA',
#   'summonerName': 'Cerecof1',
#   'leaguePoints': 1047,
#   'wins': 339,
#   'losses': 298,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'ZfpAwAfOE4sSkmK3F2LBqNj3lBklWog4Iw2eTpGzrNkU5NtP',
#   'summonerName': 'Subbex',
#   'leaguePoints': 1045,
#   'wins': 255,
#   'losses': 212,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'f7KxO4TbumZ4i_-GZ7Cv15v6BhkTFC8xyOL-sHCPXMyvooLyrgMdRJ7ECA',
#   'summonerName': 'Dark Spiderman',
#   'leaguePoints': 1044,
#   'wins': 146,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '6UJnRiHM2LNc8IIYPAAvuH-DHmpSr_qD9v23Am1ILXVBdZ4',
#   'summonerName': 'Tentrishious',
#   'leaguePoints': 1043,
#   'wins': 110,
#   'losses': 70,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'Hecrrq0XgJ6pi4wZHrZQjYycTjiGrMcaORxJfT8fpsrARswpJIw4CDmRSQ',
#   'summonerName': 'V1T Upset',
#   'leaguePoints': 1042,
#   'wins': 293,
#   'losses': 251,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': '0THVrgfBCdnBR1fjyTWvXETmiCKcQ_bH5Z-WeIQPsj-PeXXr',
#   'summonerName': 'gigabean',
#   'leaguePoints': 1042,
#   'wins': 214,
#   'losses': 168,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'Cc6QXIrMZrgho3avcUEBmBgfLocKGS9XMowCBx6SxPlLceY',
#   'summonerName': 'TTVbigcheektimmy',
#   'leaguePoints': 1041,
#   'wins': 451,
#   'losses': 402,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'PdKVgAfs47INUp5dXV4ywTJHT1oK7tRrQGoHb37lESbEZ_Q',
#   'summonerName': 'head issue1',
#   'leaguePoints': 1041,
#   'wins': 388,
#   'losses': 349,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'leagueId': 'ffb51787-a612-327d-ab46-d826666d508d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'Q1CxOOl4lOFwXednIzDRgK2JJBENzAyCBPVRVt3Y1Fm9u0U',
#   'summonerName': 'REVIENS A KONOHA',
#   'leaguePoints': 1041,
#   'wins': 258,
#   'losses': 220,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True}]

# %%
import pandas as pd

datos = pd.DataFrame(datos)

# %%
datos
# Out:
#                                  leagueId        queueType        tier rank  \
# 0    ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
# 1    ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
# 2    ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
# 3    ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
# 4    ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
# ..                                    ...              ...         ...  ...
# 200  ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
# 201  ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
# 202  ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
# 203  ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
# 204  ffb51787-a612-327d-ab46-d826666d508d  RANKED_SOLO_5x5  CHALLENGER    I
#
#                                             summonerId      summonerName  \
# 0     J5qBaV6G_yzlkoMmyhdZ8MNMEz_kEGWBsG9NpRPjBweWZfDR         NattyNatt
# 1      DgjHY5TXZ2RzAVgBxPv4l3yVurzDMiaPHnytOF4W7rgsH2U    Razørk Activoo
# 2      Bz89KoPOnCfJ0XeATw5OY3BRdSeNXpylI5gZiTmX8zzRDTw          WOOOLITE
# 3    q8k_YgHmwi6QIsbH7ehmbOeGPgjHyZXQ1xd_SCtzF2juBm...       Stomme Eend
# 4    5XlaL-UN5fE5aoxDTWLZm-XFW_R_-wLbzJQ5fwoUbACdAf...             frygo
# ..                                                 ...               ...
# 200  Hecrrq0XgJ6pi4wZHrZQjYycTjiGrMcaORxJfT8fpsrARs...         V1T Upset
# 201   0THVrgfBCdnBR1fjyTWvXETmiCKcQ_bH5Z-WeIQPsj-PeXXr          gigabean
# 202    Cc6QXIrMZrgho3avcUEBmBgfLocKGS9XMowCBx6SxPlLceY  TTVbigcheektimmy
# 203    PdKVgAfs47INUp5dXV4ywTJHT1oK7tRrQGoHb37lESbEZ_Q       head issue1
# 204    Q1CxOOl4lOFwXednIzDRgK2JJBENzAyCBPVRVt3Y1Fm9u0U  REVIENS A KONOHA
#
#      leaguePoints  wins  losses  veteran  inactive  freshBlood  hotStreak
# 0            1824   626     537     True     False       False       True
# 1            1757   293     211    False     False       False      False
# 2            1590   413     329    False     False       False      False
# 3            1568   235     147     True     False       False      False
# 4            1545   465     397     True     False       False      False
# ..            ...   ...     ...      ...       ...         ...        ...
# 200          1042   293     251     True     False       False      False
# 201          1042   214     168    False     False       False      False
# 202          1041   451     402    False     False        True       True
# 203          1041   388     349    False     False        True      False
# 204          1041   258     220    False     False       False       True
#
# [205 rows x 13 columns]

# %%
datos['leaguePoints']
# Out:
# 0      1824
# 1      1757
# 2      1590
# 3      1568
# 4      1545
#        ...
# 200    1042
# 201    1042
# 202    1041
# 203    1041
# 204    1041
# Name: leaguePoints, Length: 205, dtype: int64
